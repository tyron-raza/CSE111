# %% [markdown]
# TASK 1

# %%
class Calculator:
  def __init__(self):
    print("Let’s Calculate!")
  def add(self, x, y):
    return x+y 
  def subtraction(self, x, y):
    return x-y
  def multiplication(self, x, y):
    return x*y
  def division(self, x, y):
    return x/y 


input1= int(input())
operator= input()
input2= int(input())
a= Calculator()
print("Value 1:", input1)
print("Operator:", operator)
print("Value 2:", input2) 
if operator=="+":
  print("Result:", a.add(input1, input2))
if operator=="-":
  print("Result:",a.subtraction(input1,input2))
if operator=="*":
  print("Result:",a.multiplication(input1,input2))
if operator=="/":
  print("Result:",a.division(input1,input2))
# Out:
# 1
# +
# 3
# Let’s Calculate!
# Value 1: 1
# Operator: +
# Value 2: 3
# Result: 4

# %% [markdown]
# TASK 2

# %%
class Course:

  def __init__(self, name, faculty, section):
    self.name= name
    self.faculty= faculty
    self.section= section
  def detail(self):
    print(self.name+" - "+self.faculty+" -",self.section)

c1 = Course("CSE110", "TBA", 8)
c1.detail()
print("===============")
c2 = Course("CSE111", "TBA", 9)
c2.detail()
# Out:
# CSE110 - TBA - 8
# ===============
# CSE111 - TBA - 9

# %% [markdown]
# TASK 3

# %%
class Patient:

  def __init__(self, name, age ,weight, height):
    self.name= name
    self.age= age
    self.weight= weight
    self.height= height
  def printDetails(self):
    print("Name:",self.name)
    print("Age",self.age)
    print("Weight:",self.weight)
    print("Height:",self.height)
    print("BMI:", self.weight/((self.height/100)**2))


p1 = Patient("A", 55, 63.0, 158.0)
p1.printDetails()
print("====================")
p2 = Patient("B", 53, 61.0, 149.0)
p2.printDetails()
# Out:
# Name: A
# Age 55
# Weight: 63.0
# Height: 158.0
# BMI: 25.236340330075304
# ====================
# Name: B
# Age 53
# Weight: 61.0
# Height: 149.0
# BMI: 27.476239809017613

# %% [markdown]
# TASK 4

# %%
class Vehicle:
  def __init__(self):
    self.position= [0,0]
  def moveUp(self):
    self.position[1]+=1
  def moveDown(self):
    self.position[1]-=1
  def moveLeft(self):
    self.position[0]-=1
  def moveRight(self): 
    self.position[0]+=1
  def print_position(self):
    print(tuple(self.position)) 
car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0, 0)
# (0, 1)
# (-1, 1)
# (-1, 0)

# %% [markdown]
# TASK 5

# %%
class Shape:
  def __init__(self, name, i1,i2):
    self.name= name
    self.i1= i1
    self.i2= i2
  def area(self):
    if self.name=="Triangle" or self.name=="Rhombus":
      print("Area:", .5*self.i1*self.i2)
    elif self.name=="Square" or self.name=="Rectangle":
      print("Area:", self.i1*self.i2)
    else:
      print("Area: Unknown Shape")

triangle = Shape("Triangle",10,25)
triangle.area()
print("==========================")
square = Shape("Square",10,10)
square.area()
print("==========================")
rhombus = Shape("Rhombus",18,25)
rhombus.area()
print("==========================")
rectangle = Shape("Rectangle",15,30)
rectangle.area()
print("==========================")
trapezium = Shape("Trapezium",15,30)
trapezium.area()
# Out:
# Area: 125.0
# ==========================
# Area: 100
# ==========================
# Area: 225.0
# ==========================
# Area: 450
# ==========================
# Area: Unknown Shape

# %% [markdown]
# TASK 6

# %%
class Calculator:
  def __init__(self):
    print("")
  def calculate(self, x, y, operator):
    self.x=x
    self.y=y
    self.operator= operator
    if operator=="+":
      self.result= self.x+self.y 
      return self.result
    elif operator=="-":
      self.result= self.x-self.y
      return self.result
    elif operator=="*":
      self.result= self.x*self.y
      return self.result
    elif operator=="/":
      self.result= self.x/self.y
      return self.result
  def showCalculation(self):
    print(self.x, self.operator, self.y, "=",  self.result)
    pass
c1 = Calculator()
print("==================")
val = c1.calculate(10, 20, '+')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 10, '-')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 5, '*')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 16, '/')
print("Returned value:", val)
c1.showCalculation()
# Out:
# ==================
# Returned value: 30
# 10 + 20 = 30
# ==================
# Returned value: 20
# 30 - 10 = 20
# ==================
# Returned value: 100
# 20 * 5 = 100
# ==================
# Returned value: 6.25
# 100 / 16 = 6.25

# %% [markdown]
# TASK 7

# %%
class Student:
  def __init__(self, name, id, dept, cglist):
    self.name= name
    self.id=id
    self.dept=dept
    self.cglist=cglist
    self.cgpa=0


  def calculate_CGPA(self):
    for i in self.cglist:
      self.cgpa+= (3*i)/(3*len(self.cglist))
      
  def print_details(self):
    print("Name:" , self.name)
    print("Department:", self.dept)
    print("CGPA:", self.cgpa)
    if self.cgpa>3.80:
      print("Your academic standing is 'Highest Distinction'")
    elif self.cgpa>3.65:
      print("Your academic standing is 'High Distinction'")
    elif self.cgpa>3.50:
      print("Your academic standing is 'Distinction'")
    elif self.cgpa>2.00:
      print("Your academic standing is 'Satisfactory'")
    else:
      print("Sorry, you cannot graduate")



s1 = Student('Dora', '15995599','CSE', [4,3.7,3.7,4])
s1.calculate_CGPA()
print("==========================")
s1.print_details()
print("==========================")
s2 = Student('Pingu', '12312322', 'EEE', [1.7,1.3,1.3,1.3,1])
s2.calculate_CGPA()
print("==========================")
s2.print_details()
print("==========================") 
s3 = Student('Bob', '13311331', 'CSE', [2,3,3,3.7,2.7,2.7])
s3.calculate_CGPA()
print("==========================")
s3.print_details()
# Out:
# ==========================
# Name: Dora
# Department: CSE
# CGPA: 3.8500000000000005
# Your academic standing is 'Highest Distinction'
# ==========================
# ==========================
# Name: Pingu
# Department: EEE
# CGPA: 1.32
# Sorry, you cannot graduate
# ==========================
# ==========================
# Name: Bob
# Department: CSE
# CGPA: 2.85
# Your academic standing is 'Satisfactory'

# %% [markdown]
# TASK 8

# %%
class Shinobi:
  def __init__(self, name, rank):
    self.name=name
    self.rank=rank
    self.missions=0
    self.salary=0
  def calSalary(self, missions):
    self.missions=missions
    if self.rank=="Genin":
      self.salary = self.missions*50
    elif self.rank=="Chunin":
      self.salary = self.missions*100
    else:
      self.salary = self.missions*500
  def printInfo(self):
    print("Name:" , self.name)
    print("Rank:" , self.rank)
    print("Number of mission:", self.missions)
    print("Salary:", self.salary)
  def changeRank(self, rank):
    self.rank=rank



naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 250
# ====================
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ====================
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500

# %% [markdown]
# TASK 9

# %%
class Programmer:
  def __init__(self, name, lang, exp):
    print("Horray! A new programmer is born")
    self.name= name
    self.lang= lang
    self.exp= exp
  def printDetails(self):
    print("Name:", self.name)
    print("Language:", self.lang)
    print("Experience:", self.exp, "Years")
  def addExp(self, add1):
    print("Updating experience of", self.name)
    self.exp+=add1




p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 Years
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 Years
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 Years
# Updating experience of Jon Snow
# Name: Jon Snow
# Language: Python
# Experience: 9 Years

# %% [markdown]
# TASK 10

# %%
class UberEats:
  def __init__(self, name, cell, loc):
    self.name=name
    self.cell=cell
    self.loc=loc
    self.item1=""
    self.item2=""
    self.price1=0
    self.price2=0
    self.itemlist={}
    print(self.name,", Welcome to UberEats!")
  def add_items(self, item1, item2, price1, price2):
    self.item1= item1
    self.item2= item2
    self.price1= price1
    self.price2= price2
    self.itemlist= {self.item1:self.price1, self.item2:self.price2}
   
  def print_order_detail(self):
    print("Name", self.name, ", Phone:", self.cell, ", Address:",self.loc, ", Orders:", self.itemlist)
    total=self.price1+self.price2
    returnval= "Total Paid Amount:"+str(total)
    return returnval
  
order1 = UberEats("Shakib", "01719658xxx", "Mohakhali")
print("=========================")
order1.add_items("Burger", "Coca Cola", 220, 50)
print("=========================")
print(order1.print_order_detail())
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara")
print("=========================")
order2.add_items("Pineapple", "Dairy Milk", 80, 70)
print("=========================")
print(order2.print_order_detail())
# Out:
# Shakib , Welcome to UberEats!
# =========================
# =========================
# Name Shakib , Phone: 01719658xxx , Address: Mohakhali , Orders: {'Burger': 220, 'Coca Cola': 50}
# Total Paid Amount:270
# =========================
# Siam , Welcome to UberEats!
# =========================
# =========================
# Name Siam , Phone: 01719659xxx , Address: Uttara , Orders: {'Pineapple': 80, 'Dairy Milk': 70}
# Total Paid Amount:150

# %% [markdown]
# TASK 11

# %%
class Spotify:
  def __init__(self, songlist):
    self.songlist= songlist
    self.slno=0

  def playing_number(self, slno):
    self.slno=slno
    if slno>len(self.songlist):
      result= str(self.slno)+" " + "number song not found. Your playlist has"+" "+str(len(self.songlist))+" "+"songs only"
      return result
    else:
      result= "##############################\n Playing"+ " "+str(self.slno) +" "+ "number song for you\n Song name:"+" " +str(self.songlist[self.slno-1])
      return result


  def add_to_playlist(self, songname):
    self.songlist.append(songname)

user1 = Spotify(["See You Again", "Uptown Funk", "Hello"])
print("=========================")
print(user1.playing_number(4))
user1.add_to_playlist("Dusk Till Dawn")
print(user1.playing_number(3))
print(user1.playing_number(4))
# Out:
# =========================
# 4 number song not found. Your playlist has 3 songs only
# ##############################
#  Playing 3 number song for you
#  Song name: Hello
# ##############################
#  Playing 4 number song for you
#  Song name: Dusk Till Dawn

# %%
class Test:
    def __init__(self):
        self.sum = 0
        self.y = 0


    def methodA(self):
        x=0
        y =0
        y = y + 7
        x = y + 11
        self.sum = x + y
        print(x , y, self.sum)


    def methodB(self):
        x = 0
        self.y = self.y + 11
        x = x + 33 + self.y
        self.sum = self.sum + x + self.y
        print(x , self.y, self.sum)

t1 = Test()
t1.methodA()
t1.methodA()
t1.methodB()
t1.methodB()
# Out:
# 18 7 25
# 18 7 25
# 44 11 80
# 55 22 157

# %%
class Scope:
    def __init__(self):
        self.x, self.y = 1, 100        
    def met1(self):
        x = 3
        x = self.x + 1
        self.y = self.y + self.x + 1
        x = self.y + self.met2() + self.y
        print(x, self.y)         
    def met2(self):
        y = 0
        print(self.x, y)
        self.x = self.x + y
        self.y = self.y + 200
        return self.x + y

q2 = Scope()
q2.met1()
q2.met2()
q2.met1()
q2.met2()
# Out:
# 1 0
# 405 302
# 1 0
# 1 0
# 1209 704
# 1 0
# 1

# %%
class Test3:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 2, 3
        msg = [0]
        msg[0] = 3
        y = self.y + msg[0]
        self.methodB(msg, msg[0])
        x = self.y + msg[0]
        self.sum = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, mg2, mg1):
        x = 0
        self.y = self.y + mg2[0]
        x = x + 33 + mg1
        self.sum = self.sum + x + self.y
        mg2[0] = self.y + mg1
        mg1 = mg1 + x + 2
        print(x, self.y, self.sum)

t3 = Test3()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 36 3 39
# 9 3 18
# 36 6 60
# 15 6 30
# 36 9 75
# 21 9 42
# 36 12 90
# 27 12 54

# %%
class Test5:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):    
        x = 0
        z = 0
        while (z < 5):
            self.y = self.y + self.sum
            x = self.y + 1
            print(x, self.y, self.sum)
            self.sum = self.sum + self.methodB(x, self.y)
            z += 1
    def methodB(self, m, n):
        x = 0
        sum = 0
        self.y = self.y + m
        x = n - 4
        sum = sum + self.y
        print(x, self.y, sum)
        return self.sum

t5 = Test5()
t5.methodA()
# Out:
# 1 0 0
# -4 1 1
# 2 1 0
# -3 3 3
# 4 3 0
# -1 7 7
# 8 7 0
# 3 15 15
# 16 15 0
# 11 31 31
